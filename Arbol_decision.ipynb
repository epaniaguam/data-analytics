# %%
import pandas as pd #Manipulación de datos
import os #Manejo de Archivos Drive

# %%
import sys

if 'google.colab' in sys.modules:
  from google.colab import drive
  drive.mount('/content/drive')
  dir = '/content/drive/MyDrive/ESIS_2024/7mo_semestre/Analitica_Datos/UNID02/TrabajoUnidad02/Data/bank'
else:
  dir = './Data/bank/'
  
os.listdir(dir)
# Out:
# ['bank-names.txt',
#  'bank.csv',
#  'bank-full.csv',
#  'bank-full.xlsx',
#  'bank-full-trad.xlsx',
#  'bank-full-trad-num.xlsx']

# %%
archivo = f'{dir}bank-full-trad.xlsx'
data_xls = pd.read_excel(archivo, sheet_name='bank-full')

# %%
data_xls.head()
# Out:
#    edad      trabajo estado_civil    educacion incumplimiento  balance  \
# 0    58      gerente       casado     superior             no     2143
# 1    44      técnico      soltero   secundario             no       29
# 2    33   empresario       casado   secundario             no        2
# 3    47       obrero       casado  desconocido             no     1506
# 4    33  desconocido      soltero  desconocido             no        1
#
#   pres_vivienda pres_personal     contacto  dia  mes  duracion_seg  campania  \
# 0            si            no  desconocido    5  may           261         1
# 1            si            no  desconocido    5  may           151         1
# 2            si            si  desconocido    5  may            76         1
# 3            si            no  desconocido    5  may            92         1
# 4            no            no  desconocido    5  may           198         1
#
#    pdias  anterior   presultado   y
# 0     -1         0  desconocido  no
# 1     -1         0  desconocido  no
# 2     -1         0  desconocido  no
# 3     -1         0  desconocido  no
# 4     -1         0  desconocido  no

# %%
df = pd.get_dummies(data = data_xls, drop_first=True)
df
# Out:
#        edad  balance  dia  duracion_seg  campania  pdias  anterior  \
# 0        58     2143    5           261         1     -1         0
# 1        44       29    5           151         1     -1         0
# 2        33        2    5            76         1     -1         0
# 3        47     1506    5            92         1     -1         0
# 4        33        1    5           198         1     -1         0
# ...     ...      ...  ...           ...       ...    ...       ...
# 45206    51      825   17           977         3     -1         0
# 45207    71     1729   17           456         2     -1         0
# 45208    72     5715   17          1127         5    184         3
# 45209    57      668   17           508         4     -1         0
# 45210    37     2971   17           361         2    188        11
#
#        trabajo_autonomo  trabajo_desconocido  trabajo_desempleado  ...  \
# 0                 False                False                False  ...
# 1                 False                False                False  ...
# 2                 False                False                False  ...
# 3                 False                False                False  ...
# 4                 False                 True                False  ...
# ...                 ...                  ...                  ...  ...
# 45206             False                False                False  ...
# 45207             False                False                False  ...
# 45208             False                False                False  ...
# 45209             False                False                False  ...
# 45210             False                False                False  ...
#
#        mes_jun  mes_mar  mes_may  mes_nov  mes_oct  mes_sep  presultado_exito  \
# 0        False    False     True    False    False    False             False
# 1        False    False     True    False    False    False             False
# 2        False    False     True    False    False    False             False
# 3        False    False     True    False    False    False             False
# 4        False    False     True    False    False    False             False
# ...        ...      ...      ...      ...      ...      ...               ...
# 45206    False    False    False     True    False    False             False
# 45207    False    False    False     True    False    False             False
# 45208    False    False    False     True    False    False              True
# 45209    False    False    False     True    False    False             False
# 45210    False    False    False     True    False    False             False
#
#        presultado_fracaso  presultado_otro   y_si
# 0                   False            False  False
# 1                   False            False  False
# 2                   False            False  False
# 3                   False            False  False
# 4                   False            False  False
# ...                   ...              ...    ...
# 45206               False            False   True
# 45207               False            False   True
# 45208               False            False   True
# 45209               False            False  False
# 45210               False             True  False
#
# [45211 rows x 43 columns]

# %% [markdown]
# ## 2. Seleccionamos las variables

# %%
covariables = df.drop(columns=['y_si'])
objetivo = df['y_si']

# %% [markdown]
# ## 3. Entrenamiento del Árbol de decisión

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
model = DecisionTreeClassifier(max_depth=4)

# %%
model.fit(X=covariables, y=objetivo)
# Out:
# DecisionTreeClassifier(max_depth=4)

# %% [markdown]
# ## 4. Visualizar Módelo

# %%
from sklearn.tree import plot_tree
import matplotlib.pyplot as plt

# %%
plt.figure(figsize=(26, 9))
plot_tree(decision_tree=model, feature_names=covariables.columns, filled=True, fontsize=8);

# %% [markdown]
#  ## 5. Evaluacion de prediccion

# %%
y_pred = model.predict(covariables)
df['y_pred'] = y_pred

# %%
df.sample(10)[['y_si','y_pred']]
# Out:
#         y_si  y_pred
# 12880  False   False
# 43671   True    True
# 2003   False   False
# 15297  False   False
# 11507   True    True
# 35130  False   False
# 6920   False   False
# 5755   False   False
# 37451  False   False
# 11199  False   False

# %%
(df['y_si'] == df['y_pred']).mean()
# Out:
# 0.9021698259273185

# %%
len(df[ df['y_si']!= df['y_pred'] ]) ## en 4423 datos falla el algoitmo
# Out:
# 4423
